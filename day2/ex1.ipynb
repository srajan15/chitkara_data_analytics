# %%
print(2 + 8)
# Out:
# 10

# %%
if(5 == 6):
  print("its equal")
else:
  print(2 + 8)
  print("not equal")
  print(8 / 2)
# Out:
# 10
# not equal
# 4.0

# %%
age = 18
if(age >= 18):
  print("you can apply for driving licence")
else:
  print("you can't apply for driving licence")

# %%
marks = 65
if(marks > 80):
  print("you can apply for data analytics jobs")
elif(marks < 60):
  print("you can't apply for any jobs")
else:
  print("you can apply for management jobs")
# Out:
# you can apply for management jobs

# %%
age = int(input("enter your age"))
haveDrivingLicense = bool(input("enter nothing for false and true for true"))
if(age >= 18):
  if(haveDrivingLicense):
    print("you can drive")
  else:
    print("for driving you have to apply for driving license")
else:
  print("you can't drive better drive cycle")
# Out:
# you can't drive better drive cycle

# %%
print(r""" _____________________
|  _________________  |
| | JO           0. | |
| |_________________| |
|  ___ ___ ___   ___  |
| | 7 | 8 | 9 | | + | |
| |___|___|___| |___| |
| | 4 | 5 | 6 | | - | |
| |___|___|___| |___| |
| | 1 | 2 | 3 | | x | |
| |___|___|___| |___| |
| | . | 0 | = | | / | |
| |___|___|___| |___| |
|_____________________|
""")
num1 = float(input("enter number 1"))
num2 = float(input("enter number 2"))
choice = int(input("enter 1 for addition 2 for subtraction 3 for division 4 for multiplication"))
if(choice == 1):
  result = num1 + num2
  print(result)
elif(choice == 2):
  result = num1 - num2
  print(result)
elif(choice == 3):
  result = num1 / num2
  print(result)
elif(choice == 4):
  result = num1 * num2
  print(result)
else:
  print("invalid syntax")
# Out:
#  _____________________
# |  _________________  |
# | | JO           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
