# %% [markdown]
# # Module 4 — NumPy Array Operations & Mathematical Functions
#
# ---
#
# # 1️⃣ Introduction to the Topic
#
# One of the **biggest advantages of NumPy** is that it allows us to perform **mathematical operations on entire arrays at once**.
#
# This feature is called:
# **Vectorized Operations**
#
# Instead of using loops, NumPy performs calculations **directly on arrays**, which makes programs:
# - Faster
# - Shorter
# - Easier to read
#
# In this module we will learn:
# - Arithmetic operations on arrays
# - Element-wise operations
# - Mathematical functions
# - Introduction to **broadcasting**
#
# These concepts are **very important in Data Science and Machine Learning**.

# %% [markdown]
# ---
#
# # 2️⃣ Explanation of Concepts in Simple Language
#
# ## Arithmetic Operations in NumPy
#
# NumPy allows us to perform arithmetic operations like:
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Power
#
# These operations are applied **element by element**.
# This is called **Element-Wise Operation**.
#
# **Example:**
# ```
# Array A = [1 2 3]
# Array B = [4 5 6]
#
# Addition result = [5 7 9]
# ```
# Each element is added with the element in the same position.
#
#
#
# ---
#
# ## Vectorized Operations
#
# Normally in Python lists we need **loops** to perform calculations.
# NumPy allows us to do this **without loops**.
#
# This is called **Vectorization**.
# Vectorization makes NumPy **much faster than normal Python lists**.

# %% [markdown]
# ---
#
# # 3️⃣ Syntax
#
# Basic arithmetic operations:
# ```python
# array1 + array2
# array1 - array2
# array1 * array2
# array1 / array2
# array ** power
# ```
#
# NumPy also provides explicit functions:
# ```python
# np.add()
# np.subtract()
# np.multiply()
# np.divide()
# np.power()
# np.sqrt()
# np.exp()
# np.log()
# ```

# %% [markdown]
# ---
#
# # 4️⃣ Code Examples
#
# ---
#
# # Example 1 — Addition of Arrays

# %%
import numpy as np

# Create two arrays of the same size
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# Add them together using the '+' operator
result = a + b

print(result)

# %% [markdown]
# ### Output
# ```
# [5 7 9]
# ```
# ### Explanation
# ```
# 1+4 = 5
# 2+5 = 7
# 3+6 = 9
# ```
# NumPy adds elements **position by position**.
#
# ---
#
# # Example 2 — Subtraction

# %%
import numpy as np

a = np.array([10, 20, 30])
b = np.array([1, 2, 3])

# Subtract array 'b' from array 'a'
print(a - b)

# %% [markdown]
# ### Output
# ```
# [ 9 18 27 ]
# ```
# ### Explanation
# ```
# 10 - 1 = 9
# 20 - 2 = 18
# 30 - 3 = 27
# ```
#
# ---
#
# # Example 3 — Multiplication

# %%
import numpy as np

a = np.array([2, 4, 6])
b = np.array([3, 5, 7])

# Multiply elements at corresponding positions
print(a * b)

# %% [markdown]
# ### Output
# ```
# [ 6 20 42]
# ```
# ### Explanation
# ```
# 2*3 = 6
# 4*5 = 20
# 6*7 = 42
# ```
# This is **element-wise multiplication**.
#
# ---
#
# # Example 4 — Division

# %%
import numpy as np

a = np.array([10, 20, 30])

# Divide every element in the array by 2
print(a / 2)

# %% [markdown]
# ### Output
# ```
# [ 5. 10. 15.]
# ```
# ### Explanation
# Each element is divided by **2**.
#
# ---
#
# # Example 5 — Power Operation

# %%
import numpy as np

a = np.array([2, 3, 4])

# Square every element in the array (power of 2)
print(a ** 2)

# %% [markdown]
# ### Output
# ```
# [ 4  9 16]
# ```
# ### Explanation
# ```
# 2² = 4
# 3² = 9
# 4² = 16
# ```
#
# ---
#
# # 5️⃣ NumPy Mathematical Functions
#
# NumPy provides many built-in mathematical functions.
# Some important ones are:
#
# | Function  | Purpose     |
# | --------- | ----------- |
# | np.sqrt() | Square root |
# | np.exp()  | Exponential |
# | np.log()  | Logarithm   |
# | np.sin()  | Sine        |
# | np.cos()  | Cosine      |
#
# ---
#
# # Example 6 — Square Root

# %%
import numpy as np

arr = np.array([4, 9, 16, 25])

# Calculate the square root of each element
print(np.sqrt(arr))

# %% [markdown]
# ### Output
# ```
# [2. 3. 4. 5.]
# ```
# ### Explanation
# Square root of each element is calculated.
#
# ---
#
# # Example 7 — Log Function

# %%
import numpy as np

arr = np.array([1, 2, 3])

# Calculate the natural logarithm for each element
print(np.log(arr))

# %% [markdown]
# ### Output
# ```
# [0.         0.69314718 1.09861229]
# ```
# ### Explanation
# NumPy calculates **natural logarithm (ln)**.
#
# ---
#
# # Example 8 — Exponential Function

# %%
import numpy as np

arr = np.array([1, 2, 3])

# Calculate the exponential (e^x) for each element
print(np.exp(arr))

# %% [markdown]
# ### Output
# ```
# [ 2.718  7.389 20.085 ]
# ```
# ### Explanation
# This calculates **e^x** for each element.
#
# ---
#
# # 6️⃣ Broadcasting (Introduction)
#
# Broadcasting means performing operations between arrays of **different sizes**.
#
# **Example:**
# ```
# Array = [1 2 3]
# Number = 5
# ```
#
# NumPy automatically converts it to:
# ```
# [1 2 3]
# [5 5 5]
# ```
# Then performs operation.
#
#
#
# ### Example

# %%
import numpy as np

a = np.array([1, 2, 3])

# Add the scalar value '5' to the entire array via broadcasting
print(a + 5)

# %% [markdown]
# ### Output
# ```
# [6 7 8]
# ```
# ### Explanation
# ```
# 1+5 = 6
# 2+5 = 7
# 3+5 = 8
# ```
# NumPy automatically **broadcasts the number 5** to match the array size.
#
# ---
#
# # 7️⃣ Real-World Example
#
# ### Example — Product Price Calculation
#
# Suppose product prices are:
# `[100, 200, 300]`
#
# We want to **add GST of 18%**.

# %%
import numpy as np

price = np.array([100, 200, 300])

# Multiply by 1.18 to add 18% tax to all items
gst_price = price * 1.18

print(gst_price)

# %% [markdown]
# ### Output
# ```
# [118. 236. 354.]
# ```
# ### Explanation
# NumPy applied the multiplication to **all prices automatically**.
#
# ---
#
# # 8️⃣ Important Tips / Common Mistakes
#
# ### Tip 1
# Arrays must usually have **same size for element-wise operations**.
#
# **Example:**
# ```
# [1 2 3]
# [4 5 6]
# ```
# Works correctly.
#
# ---
#
# ### Tip 2
# Broadcasting works when **one value or compatible shapes exist**.
#
# **Example:**
# ```python
# array + number
# ```
# Works.
#
# ---
#
# ### Tip 3
# Avoid loops when using NumPy. Use **vectorized operations** instead to keep your code fast and clean.
#
# ---
#
# # 9️⃣ Summary
#
# In this module we learned:
# - NumPy supports **array arithmetic operations**
# - Operations are **element-wise**
# - Vectorization makes NumPy **fast**
# - Common operations include:
#   - addition
#   - subtraction
#   - multiplication
#   - division
#   - power
# - NumPy provides mathematical functions like:
#   - sqrt
#   - log
#   - exp
# - Broadcasting allows operations with **different shapes**
#
# These operations are widely used in:
# - Data analysis
# - Machine learning
# - Deep learning
# - Scientific computing
#
# ---
#
# # 🔟 Practice Questions
#
# ### Question 1
# Create two arrays:
# ```
# [2, 4, 6]
# [1, 3, 5]
# ```
# Add them using NumPy.
#
# ---
#
# ### Question 2
# Create an array `[5, 10, 15]` and multiply each element by **3**.
#
# ---
#
# ### Question 3
# Write a NumPy program to calculate **square root of** `[16, 25, 36]`.
