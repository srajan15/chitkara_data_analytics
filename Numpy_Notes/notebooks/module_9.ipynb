# %% [markdown]
# # Module 9 — NumPy Statistical and Aggregation Functions
#
# ---
#
# # 1️⃣ Introduction to the Topic
#
# When working with data, we often need to summarize and analyze numbers.
#
# For example:
# - Find the average marks of students
# - Find the highest temperature
# - Find the minimum sales value
# - Calculate standard deviation
#
# NumPy provides many statistical and aggregation functions that help us analyze data easily.
#
# These functions are heavily used in:
# - Data Analysis
# - Exploratory Data Analysis (EDA)
# - Machine Learning
# - Scientific Computing
#
# Important functions we will learn:
# - sum()
# - mean()
# - median()
# - min()
# - max()
# - argmax()
# - argmin()
# - std()
# - var()

# %% [markdown]
# ---
#
# # 2️⃣ Explanation of Concepts in Simple Language
#
# ## What are Aggregation Functions?
#
# Aggregation functions combine multiple values into a single result.
#
# Example array:
# ```text
# [10 20 30 40]
# ```
#
# Aggregation results:
#
# | Operation | Result |
# |-----------|--------|
# | Sum       | 100    |
# | Mean      | 25     |
# | Min       | 10     |
# | Max       | 40     |
#
# These functions help us understand datasets quickly.

# %% [markdown]
# ---
#
# # 3️⃣ Syntax
#
# Basic syntax:
#
# ```python
# np.function_name(array)
# ```
#
# Examples:
#
# ```python
# np.sum(array)
# np.mean(array)
# np.median(array)
# np.min(array)
# np.max(array)
# np.std(array)
# np.var(array)
# ```

# %% [markdown]
# ---
#
# # 4️⃣ Code Examples

# %% [markdown]
# # Example 1 — Sum of Elements

# %%
import numpy as np

arr = np.array([10,20,30,40])

print(np.sum(arr))

# %% [markdown]
# ### Output
# ```text
# 100
# ```
#
# Explanation:
# 10 + 20 + 30 + 40 = 100

# %% [markdown]
# # Example 2 — Mean (Average)

# %%
import numpy as np

arr = np.array([10,20,30,40])

print(np.mean(arr))

# %% [markdown]
# ### Output
# ```text
# 25.0
# ```
#
# Explanation:
# (10 + 20 + 30 + 40) / 4 = 25

# %% [markdown]
# # Example 3 — Median

# %%
import numpy as np

arr = np.array([10,20,30,40,50])

print(np.median(arr))

# %% [markdown]
# ### Output
# ```text
# 30
# ```

# %% [markdown]
# # Example 4 — Minimum Value

# %%
import numpy as np

arr = np.array([15,25,10,40])

print(np.min(arr))

# %% [markdown]
# ### Output
# ```text
# 10
# ```

# %% [markdown]
# # Example 5 — Maximum Value

# %%
import numpy as np

arr = np.array([15,25,10,40])

print(np.max(arr))

# %% [markdown]
# ### Output
# ```text
# 40
# ```

# %% [markdown]
# # Example 6 — argmax()

# %%
import numpy as np

arr = np.array([10,25,18,40])

print(np.argmax(arr))

# %% [markdown]
# Explanation:
# Index of maximum value (40) is 3.

# %% [markdown]
# # Example 7 — argmin()

# %%
import numpy as np

arr = np.array([10,25,18,5])

print(np.argmin(arr))

# %% [markdown]
# Explanation:
# Index of minimum value (5) is 3.

# %% [markdown]
# # Example 8 — Standard Deviation

# %%
import numpy as np

arr = np.array([10,20,30,40])

print(np.std(arr))

# %% [markdown]
# # Example 9 — Variance

# %%
import numpy as np

arr = np.array([10,20,30,40])

print(np.var(arr))

# %% [markdown]
# ---
#
# # 5️⃣ Using Axis in 2D Arrays

# %%
import numpy as np

arr = np.array([[10,20,30],
                [40,50,60]])

# %% [markdown]
# ### Sum of Columns

# %%
print(np.sum(arr, axis=0))

# %% [markdown]
# ### Sum of Rows

# %%
print(np.sum(arr, axis=1))

# %% [markdown]
# ---
#
# # 6️⃣ Real-World Example
#
# ### Student Marks Analysis

# %%
import numpy as np

marks = np.array([78,85,90,66,88])

print("Average:", np.mean(marks))
print("Highest:", np.max(marks))
print("Lowest:", np.min(marks))

# %% [markdown]
# ---
#
# # 7️⃣ Important Tips
#
# ### Tip 1
# Always prefer NumPy statistical functions over manual loops.
#
# ### Tip 2
# Check array shape before axis operations using:
# ```python
# array.shape
# ```
#
# ### Tip 3
# | Function | Meaning |
# |----------|---------|
# | argmax   | index of maximum value |
# | argmin   | index of minimum value |

# %% [markdown]
# ---
#
# # 8️⃣ Summary
#
# Important NumPy statistical functions:
#
# - sum()
# - mean()
# - median()
# - min()
# - max()
# - argmax()
# - argmin()
# - std()
# - var()
#
# These are heavily used in data analysis, EDA, and machine learning.

# %% [markdown]
# ---
#
# # 9️⃣ Practice Questions
#
# ### Question 1
# Create array `[5,10,15,20]` and find the sum.
#
# ### Question 2
# Find the average marks of `[60,70,80,90]`.
#
# ### Question 3
# Find the maximum value and its index in `[12,45,30,55,20]`.
