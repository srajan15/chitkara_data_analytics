# %% [markdown]
# # Module 1: Introduction to Pandas

# %% [markdown]
# ## 1️⃣ Introduction
#
# **Pandas** is one of the most powerful Python libraries used for **data analysis and data manipulation**.
#
# It helps us to:
#
# - Organize data
# - Clean data
# - Analyze data
# - Transform data
# - Prepare data for visualization or machine learning
#
# 👉 **Pandas helps us work with structured data like tables.**
#
# Just like Excel sheets, Pandas works with **rows and columns**.

# %% [markdown]
# ### Example of Table Data
#
# | Name | Age | City |
# |------|-----|------|
# | Amit | 22  | Delhi |
# | Ravi | 25  | Mumbai |
# | Neha | 21  | Jaipur |
#
# Pandas allows easy operations on such tabular data.

# %% [markdown]
# ## 2️⃣ Why Pandas is Important
#
# Pandas is widely used in:
#
# - Data Analysis
# - Data Science
# - Machine Learning
# - Business Analytics
# - Financial Analysis
#
# ### Without Pandas
#
# Handling large datasets using Python lists or dictionaries becomes difficult.
#
# ### With Pandas
#
# We can easily:
#
# - Filter data
# - Calculate statistics
# - Clean missing values
# - Combine datasets
# - Analyze trends
#
# Major companies like **Amazon, Google, Netflix, and Uber** rely on data analysis tools such as Pandas.

# %% [markdown]
# ## 3️⃣ Key Features of Pandas
#
# ### 1. Fast Data Analysis
# Pandas can process **large datasets quickly**.
#
# ### 2. Data Cleaning
# Helps handle:
#
# - Missing values
# - Incorrect data
# - Duplicate records
#
# ### 3. Data Filtering
# Easily filter specific rows or columns.
#
# ### 4. Data Aggregation
# Supports calculations such as:
#
# - Sum
# - Mean
# - Maximum
# - Minimum
#
# ### 5. File Handling
# Pandas can read data from:
#
# - CSV
# - Excel
# - JSON
# - SQL Databases

# %% [markdown]
# ## 4️⃣ Installing Pandas
#
# Before using Pandas, we need to install it.
#
# ### Installation Command

# %%
pip install pandas

# %% [markdown]
# This command installs the Pandas library in Python.

# %% [markdown]
# ## 5️⃣ Importing Pandas
#
# Before using Pandas in a program, we must import it.
#
# ### Standard Import Syntax

# %%
import pandas as pd

# %% [markdown]
# ### Explanation
#
# `import pandas` → Imports the Pandas library.
#
# `as pd` → Creates a short alias.
#
# Instead of writing:
#
# `pandas.DataFrame()`
#
# We write:
#
# `pd.DataFrame()`
#
# This makes the code shorter and easier.

# %% [markdown]
# ## 6️⃣ Pandas Data Structures
#
# Pandas mainly provides **two important data structures**:

# %% [markdown]
# ### 1️⃣ Series
#
# A **Series** is a **one-dimensional array**.
#
# It contains:
#
# - Data
# - Index
#
# Example:
#
# 0    10
# 1    20
# 2    30
# 3    40
#
# It is similar to a **single column in Excel**.

# %% [markdown]
# ### 2️⃣ DataFrame
#
# A **DataFrame** is a **two-dimensional table**.
#
# It contains:
#
# - Rows
# - Columns
#
# Example:
#
# | Name | Age |
# |------|-----|
# | Amit | 22 |
# | Ravi | 25 |
# | Neha | 21 |
#
# This looks like an **Excel sheet or database table**.

# %% [markdown]
# ## 7️⃣ Creating a Simple Pandas Series
#
# ### Example

# %%
import pandas as pd

data = [10, 20, 30, 40]

s = pd.Series(data)
print(type(s))

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## Code Explanation
#
# ### Line 1
#
# `import pandas as pd`
#
# Imports the Pandas library.
#
# ### Line 2
#
# `data = [10, 20, 30, 40]`
#
# A Python list containing numbers.
#
# ### Line 3
#
# `s = pd.Series(data)`
#
# Converts the list into a **Pandas Series object**.
#
# ### Line 4
#
# `print(s)`
#
# Displays the Series.

# %% [markdown]
# ### Output
#
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
#
# **Explanation:**
#
# - 0,1,2,3 → Index
# - 10,20,30,40 → Data values
# - dtype → Data type

# %% [markdown]
# ## 8️⃣ Creating a Simple DataFrame
#
# ### Example

# %%
import pandas as pd

data = {
    "Name": ["Amit", "Ravi", "Neha"],
    "Age": [22, 25, 21]
}

df = pd.DataFrame(data)

print(df)

# %% [markdown]
# ## Code Explanation
#
# ### Line 1
# Import Pandas.
#
# ### Line 2–5
# Create a dictionary with two columns:
#
# - Name
# - Age
#
# ### Line 6
#
# `df = pd.DataFrame(data)`
#
# Converts the dictionary into a **DataFrame**.
#
# ### Line 7
#
# `print(df)`
#
# Displays the DataFrame.

# %% [markdown]
# ### Output
#
#     Name  Age
# 0   Amit   22
# 1   Ravi   25
# 2   Neha   21
#
# **Explanation:**
#
# - Columns → Name, Age
# - Rows → 3 records
# - Index → 0,1,2

# %% [markdown]
# ## 9️⃣ Real-World Example
#
# Imagine you are a **Data Analyst in an e-commerce company**.
#
# Dataset example:
#
# | OrderID | Customer | Price |
# |--------|----------|------|
# | 101 | Amit | 500 |
# | 102 | Ravi | 700 |
# | 103 | Neha | 450 |
#
# Using Pandas you can:
#
# - Calculate total sales
# - Find average order price
# - Filter orders above ₹500
# - Analyze customer buying patterns

# %% [markdown]
# ## 🔟 Important Tips
#
# ✔ Always import Pandas as `pd` (industry standard)
#
# ✔ Pandas works best with **tabular data**
#
# ✔ Pandas integrates well with:
#
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn

# %% [markdown]
# ## 1️⃣1️⃣ Summary
#
# In this module we learned:
#
# - What Pandas is
# - Why Pandas is used
# - Installing Pandas
# - Importing Pandas
# - Pandas data structures
# - Series
# - DataFrame
# - Creating Series and DataFrame
#
# **Pandas is the core library for data analysis in Python.**
